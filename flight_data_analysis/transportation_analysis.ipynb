# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stadiums = [
    {"city_name": "Mexico City",         "country": "Mexico", "capacity": 83000, "lat": 19.303, "lon": -99.151,  "stadium": "Estadio Azteca"},
      {"city_name": "Guadalupe",           "country": "Mexico", "capacity": 53500, "lat": 25.669, "lon": -100.247, "stadium": "Estadio BBVA"},
    {"city_name": "Zapopan",             "country": "Mexico", "capacity": 48000, "lat": 20.689, "lon": -103.467, "stadium": "Estadio Akron"},
    {"city_name": "Dallas",              "country": "USA",    "capacity": 94000, "lat": 32.748, "lon": -97.093,  "stadium": "AT&T Stadium"},
    {"city_name": "Houston",             "country": "USA",    "capacity": 72000, "lat": 29.685, "lon": -95.411,  "stadium": "NRG Stadium"},
    {"city_name": "East Rutherford",     "country": "USA",    "capacity": 82500, "lat": 40.814, "lon": -74.075,  "stadium": "MetLife Stadium"},
    {"city_name": "Atlanta",             "country": "USA",    "capacity": 75000, "lat": 33.755, "lon": -84.401,  "stadium": "Mercedes-Benz Stadium"},
    {"city_name": "Kansas City",         "country": "USA",    "capacity": 73000, "lat": 39.049, "lon": -94.484,  "stadium": "Arrowhead Stadium"},
    {"city_name": "Santa Clara",         "country": "USA",    "capacity": 71000, "lat": 37.403, "lon": -121.970, "stadium": "Levi's Stadium"},
    {"city_name": "Inglewood",           "country": "USA",    "capacity": 70000, "lat": 33.953, "lon": -118.339, "stadium": "SoFi Stadium"},
    {"city_name": "Philadelphia",        "country": "USA",    "capacity": 69000, "lat": 39.901, "lon": -75.168,  "stadium": "Lincoln Financial Field"},
    {"city_name": "Foxborough",          "country": "USA",    "capacity": 65000, "lat": 42.091, "lon": -71.264,  "stadium": "Gillette Stadium"},
    {"city_name": "Miami Gardens",       "country": "USA",    "capacity": 65000, "lat": 25.958, "lon": -80.239,  "stadium": "Hard Rock Stadium"},
        {"city_name": "Seattle",             "country": "USA",    "capacity": 69000, "lat": 47.595, "lon": -122.332, "stadium": "Lumen Field"},
    {"city_name": "Vancouver",           "country": "Canada", "capacity": 54000, "lat": 49.277, "lon": -123.112, "stadium": "BC Place"},
    {"city_name": "Toronto",             "country": "Canada", "capacity": 45000, "lat": 43.633, "lon": -79.419,  "stadium": "BMO Field"},
]
matches = matches = [
    # Group A
    {"match": 1,  "group": "A", "date": "2026-06-11", "time": "13:00", "tz": "UTC-6", "team1": "Mexico",              "team2": "South Africa",        "stadium": "Estadio Azteca",          "city_name": "Mexico City",    "country": "Mexico", "lat": 19.303, "lon": -99.151},
    {"match": 2,  "group": "A", "date": "2026-06-11", "time": "20:00", "tz": "UTC-6", "team1": "Korea Republic",          "team2": "Czechia",      "stadium": "Estadio Akron",           "city_name": "Zapopan",        "country": "Mexico", "lat": 20.689, "lon": -103.467},
    {"match": 25, "group": "A", "date": "2026-06-18", "time": "12:00", "tz": "UTC-4", "team1": "Czechia",       "team2": "South Africa",        "stadium": "Mercedes-Benz Stadium",   "city_name": "Atlanta",        "country": "USA",    "lat": 33.755, "lon": -84.401},
    {"match": 28, "group": "A", "date": "2026-06-18", "time": "19:00", "tz": "UTC-6", "team1": "Mexico",              "team2": "Korea Republic",         "stadium": "Estadio Akron",           "city_name": "Zapopan",        "country": "Mexico", "lat": 20.689, "lon": -103.467},
    {"match": 53, "group": "A", "date": "2026-06-24", "time": "19:00", "tz": "UTC-6", "team1": "Czechia",       "team2": "Mexico",              "stadium": "Estadio Azteca",          "city_name": "Mexico City",    "country": "Mexico", "lat": 19.303, "lon": -99.151},
    {"match": 54, "group": "A", "date": "2026-06-24", "time": "19:00", "tz": "UTC-6", "team1": "South Africa",        "team2": "Korea Republic",         "stadium": "Estadio BBVA",            "city_name": "Guadalupe",      "country": "Mexico", "lat": 25.669, "lon": -100.247},

    # Group B
    {"match": 3,  "group": "B", "date": "2026-06-12", "time": "15:00", "tz": "UTC-4", "team1": "Canada",              "team2": "Bosnia and Herzegovina", "stadium": "BMO Field",            "city_name": "Toronto",        "country": "Canada", "lat": 43.633, "lon": -79.419},
    {"match": 8,  "group": "B", "date": "2026-06-13", "time": "12:00", "tz": "UTC-7", "team1": "Qatar",               "team2": "Switzerland",         "stadium": "Levi's Stadium",          "city_name": "Santa Clara",    "country": "USA",    "lat": 37.403, "lon": -121.970},
    {"match": 26, "group": "B", "date": "2026-06-18", "time": "12:00", "tz": "UTC-7", "team1": "Switzerland",         "team2": "Bosnia and Herzegovina", "stadium": "SoFi Stadium",         "city_name": "Inglewood",      "country": "USA",    "lat": 33.953, "lon": -118.339},
    {"match": 27, "group": "B", "date": "2026-06-18", "time": "15:00", "tz": "UTC-7", "team1": "Canada",              "team2": "Qatar",               "stadium": "BC Place",                "city_name": "Vancouver",      "country": "Canada", "lat": 49.277, "lon": -123.112},
    {"match": 51, "group": "B", "date": "2026-06-24", "time": "12:00", "tz": "UTC-7", "team1": "Switzerland",         "team2": "Canada",              "stadium": "BC Place",                "city_name": "Vancouver",      "country": "Canada", "lat": 49.277, "lon": -123.112},
    {"match": 52, "group": "B", "date": "2026-06-24", "time": "12:00", "tz": "UTC-7", "team1": "Bosnia and Herzegovina", "team2": "Qatar",            "stadium": "Lumen Field",             "city_name": "Seattle",        "country": "USA",    "lat": 47.595, "lon": -122.332},

    # Group C
    {"match": 7,  "group": "C", "date": "2026-06-13", "time": "18:00", "tz": "UTC-4", "team1": "Brazil",              "team2": "Morocco",             "stadium": "MetLife Stadium",         "city_name": "East Rutherford","country": "USA",    "lat": 40.814, "lon": -74.075},
    {"match": 5,  "group": "C", "date": "2026-06-13", "time": "21:00", "tz": "UTC-4", "team1": "Haiti",               "team2": "Scotland",            "stadium": "Gillette Stadium",        "city_name": "Foxborough",     "country": "USA",    "lat": 42.091, "lon": -71.264},
    {"match": 30, "group": "C", "date": "2026-06-19", "time": "18:00", "tz": "UTC-4", "team1": "Scotland",            "team2": "Morocco",             "stadium": "Gillette Stadium",        "city_name": "Foxborough",     "country": "USA",    "lat": 42.091, "lon": -71.264},
    {"match": 29, "group": "C", "date": "2026-06-19", "time": "20:30", "tz": "UTC-4", "team1": "Brazil",              "team2": "Haiti",               "stadium": "Lincoln Financial Field", "city_name": "Philadelphia",   "country": "USA",    "lat": 39.901, "lon": -75.168},
    {"match": 49, "group": "C", "date": "2026-06-24", "time": "18:00", "tz": "UTC-4", "team1": "Scotland",            "team2": "Brazil",              "stadium": "Hard Rock Stadium",       "city_name": "Miami Gardens",  "country": "USA",    "lat": 25.958, "lon": -80.239},
    {"match": 50, "group": "C", "date": "2026-06-24", "time": "18:00", "tz": "UTC-4", "team1": "Morocco",             "team2": "Haiti",               "stadium": "Mercedes-Benz Stadium",   "city_name": "Atlanta",        "country": "USA",    "lat": 33.755, "lon": -84.401},

    # Group D
    {"match": 4,  "group": "D", "date": "2026-06-12", "time": "18:00", "tz": "UTC-7", "team1": "USA",       "team2": "Paraguay",            "stadium": "SoFi Stadium",            "city_name": "Inglewood",      "country": "USA",    "lat": 33.953, "lon": -118.339},
    {"match": 6,  "group": "D", "date": "2026-06-13", "time": "21:00", "tz": "UTC-7", "team1": "Australia",           "team2": "Türkiye",              "stadium": "BC Place",                "city_name": "Vancouver",      "country": "Canada", "lat": 49.277, "lon": -123.112},
    {"match": 32, "group": "D", "date": "2026-06-19", "time": "12:00", "tz": "UTC-7", "team1": "USA",       "team2": "Australia",           "stadium": "Lumen Field",             "city_name": "Seattle",        "country": "USA",    "lat": 47.595, "lon": -122.332},
    {"match": 31, "group": "D", "date": "2026-06-19", "time": "20:00", "tz": "UTC-7", "team1": "Türkiye",              "team2": "Paraguay",            "stadium": "Levi's Stadium",          "city_name": "Santa Clara",    "country": "USA",    "lat": 37.403, "lon": -121.970},
    {"match": 59, "group": "D", "date": "2026-06-25", "time": "19:00", "tz": "UTC-7", "team1": "Türkiye",              "team2": "USA",       "stadium": "SoFi Stadium",            "city_name": "Inglewood",      "country": "USA",    "lat": 33.953, "lon": -118.339},
    {"match": 60, "group": "D", "date": "2026-06-25", "time": "19:00", "tz": "UTC-7", "team1": "Paraguay",            "team2": "Australia",           "stadium": "Levi's Stadium",          "city_name": "Santa Clara",    "country": "USA",    "lat": 37.403, "lon": -121.970},

    # Group E
    {"match": 10, "group": "E", "date": "2026-06-14", "time": "12:00", "tz": "UTC-5", "team1": "Germany",             "team2": "Curaçao",             "stadium": "NRG Stadium",             "city_name": "Houston",        "country": "USA",    "lat": 29.685, "lon": -95.411},
    {"match": 9,  "group": "E", "date": "2026-06-14", "time": "19:00", "tz": "UTC-4", "team1": "Ivory Coast",         "team2": "Ecuador",             "stadium": "Lincoln Financial Field", "city_name": "Philadelphia",   "country": "USA",    "lat": 39.901, "lon": -75.168},
    {"match": 33, "group": "E", "date": "2026-06-20", "time": "16:00", "tz": "UTC-4", "team1": "Germany",             "team2": "Ivory Coast",         "stadium": "BMO Field",               "city_name": "Toronto",        "country": "Canada", "lat": 43.633, "lon": -79.419},
    {"match": 34, "group": "E", "date": "2026-06-20", "time": "19:00", "tz": "UTC-5", "team1": "Ecuador",             "team2": "Curaçao",             "stadium": "Arrowhead Stadium",       "city_name": "Kansas City",    "country": "USA",    "lat": 39.049, "lon": -94.484},
    {"match": 55, "group": "E", "date": "2026-06-25", "time": "16:00", "tz": "UTC-4", "team1": "Curaçao",             "team2": "Ivory Coast",         "stadium": "Lincoln Financial Field", "city_name": "Philadelphia",   "country": "USA",    "lat": 39.901, "lon": -75.168},
    {"match": 56, "group": "E", "date": "2026-06-25", "time": "16:00", "tz": "UTC-4", "team1": "Ecuador",             "team2": "Germany",             "stadium": "MetLife Stadium",         "city_name": "East Rutherford","country": "USA",    "lat": 40.814, "lon": -74.075},

    # Group F
    {"match": 11, "group": "F", "date": "2026-06-14", "time": "15:00", "tz": "UTC-5", "team1": "Netherlands",         "team2": "Japan",               "stadium": "AT&T Stadium",            "city_name": "Dallas",         "country": "USA",    "lat": 32.748, "lon": -97.093},
    {"match": 12, "group": "F", "date": "2026-06-14", "time": "20:00", "tz": "UTC-6", "team1": "Sweden",              "team2": "Tunisia",             "stadium": "Estadio BBVA",            "city_name": "Guadalupe",      "country": "Mexico", "lat": 25.669, "lon": -100.247},
    {"match": 35, "group": "F", "date": "2026-06-20", "time": "12:00", "tz": "UTC-5", "team1": "Netherlands",         "team2": "Sweden",              "stadium": "NRG Stadium",             "city_name": "Houston",        "country": "USA",    "lat": 29.685, "lon": -95.411},
    {"match": 36, "group": "F", "date": "2026-06-20", "time": "22:00", "tz": "UTC-6", "team1": "Tunisia",             "team2": "Japan",               "stadium": "Estadio BBVA",            "city_name": "Guadalupe",      "country": "Mexico", "lat": 25.669, "lon": -100.247},
    {"match": 57, "group": "F", "date": "2026-06-25", "time": "18:00", "tz": "UTC-5", "team1": "Japan",               "team2": "Sweden",              "stadium": "AT&T Stadium",            "city_name": "Dallas",         "country": "USA",    "lat": 32.748, "lon": -97.093},
    {"match": 58, "group": "F", "date": "2026-06-25", "time": "18:00", "tz": "UTC-5", "team1": "Tunisia",             "team2": "Netherlands",         "stadium": "Arrowhead Stadium",       "city_name": "Kansas City",    "country": "USA",    "lat": 39.049, "lon": -94.484},

    # Group G
    {"match": 16, "group": "G", "date": "2026-06-15", "time": "12:00", "tz": "UTC-7", "team1": "Belgium",             "team2": "Egypt",               "stadium": "Lumen Field",             "city_name": "Seattle",        "country": "USA",    "lat": 47.595, "lon": -122.332},
    {"match": 15, "group": "G", "date": "2026-06-15", "time": "18:00", "tz": "UTC-7", "team1": "Iran",                "team2": "New Zealand",         "stadium": "SoFi Stadium",            "city_name": "Inglewood",      "country": "USA",    "lat": 33.953, "lon": -118.339},
    {"match": 39, "group": "G", "date": "2026-06-21", "time": "12:00", "tz": "UTC-7", "team1": "Belgium",             "team2": "Iran",                "stadium": "SoFi Stadium",            "city_name": "Inglewood",      "country": "USA",    "lat": 33.953, "lon": -118.339},
    {"match": 40, "group": "G", "date": "2026-06-21", "time": "18:00", "tz": "UTC-7", "team1": "New Zealand",         "team2": "Egypt",               "stadium": "BC Place",                "city_name": "Vancouver",      "country": "Canada", "lat": 49.277, "lon": -123.112},
    {"match": 63, "group": "G", "date": "2026-06-26", "time": "20:00", "tz": "UTC-7", "team1": "Egypt",               "team2": "Iran",                "stadium": "Lumen Field",             "city_name": "Seattle",        "country": "USA",    "lat": 47.595, "lon": -122.332},
    {"match": 64, "group": "G", "date": "2026-06-26", "time": "20:00", "tz": "UTC-7", "team1": "New Zealand",         "team2": "Belgium",             "stadium": "BC Place",                "city_name": "Vancouver",      "country": "Canada", "lat": 49.277, "lon": -123.112},

    # Group H
    {"match": 14, "group": "H", "date": "2026-06-15", "time": "12:00", "tz": "UTC-4", "team1": "Spain",               "team2": "Cape Verde",          "stadium": "Mercedes-Benz Stadium",   "city_name": "Atlanta",        "country": "USA",    "lat": 33.755, "lon": -84.401},
    {"match": 13, "group": "H", "date": "2026-06-15", "time": "18:00", "tz": "UTC-4", "team1": "Saudi Arabia",        "team2": "Uruguay",             "stadium": "Hard Rock Stadium",       "city_name": "Miami Gardens",  "country": "USA",    "lat": 25.958, "lon": -80.239},
    {"match": 38, "group": "H", "date": "2026-06-21", "time": "12:00", "tz": "UTC-4", "team1": "Spain",               "team2": "Saudi Arabia",        "stadium": "Mercedes-Benz Stadium",   "city_name": "Atlanta",        "country": "USA",    "lat": 33.755, "lon": -84.401},
    {"match": 37, "group": "H", "date": "2026-06-21", "time": "18:00", "tz": "UTC-4", "team1": "Uruguay",             "team2": "Cape Verde",          "stadium": "Hard Rock Stadium",       "city_name": "Miami Gardens",  "country": "USA",    "lat": 25.958, "lon": -80.239},
    {"match": 65, "group": "H", "date": "2026-06-26", "time": "19:00", "tz": "UTC-5", "team1": "Cape Verde",          "team2": "Saudi Arabia",        "stadium": "NRG Stadium",             "city_name": "Houston",        "country": "USA",    "lat": 29.685, "lon": -95.411},
    {"match": 66, "group": "H", "date": "2026-06-26", "time": "18:00", "tz": "UTC-6", "team1": "Uruguay",             "team2": "Spain",               "stadium": "Estadio Akron",           "city_name": "Zapopan",        "country": "Mexico", "lat": 20.689, "lon": -103.467},

    # Group I
    {"match": 17, "group": "I", "date": "2026-06-16", "time": "15:00", "tz": "UTC-4", "team1": "France",              "team2": "Senegal",             "stadium": "MetLife Stadium",         "city_name": "East Rutherford","country": "USA",    "lat": 40.814, "lon": -74.075},
    {"match": 18, "group": "I", "date": "2026-06-16", "time": "18:00", "tz": "UTC-4", "team1": "Iraq",                "team2": "Norway",              "stadium": "Gillette Stadium",        "city_name": "Foxborough",     "country": "USA",    "lat": 42.091, "lon": -71.264},
    {"match": 42, "group": "I", "date": "2026-06-22", "time": "17:00", "tz": "UTC-4", "team1": "France",              "team2": "Iraq",                "stadium": "Lincoln Financial Field", "city_name": "Philadelphia",   "country": "USA",    "lat": 39.901, "lon": -75.168},
    {"match": 41, "group": "I", "date": "2026-06-22", "time": "20:00", "tz": "UTC-4", "team1": "Norway",              "team2": "Senegal",             "stadium": "MetLife Stadium",         "city_name": "East Rutherford","country": "USA",    "lat": 40.814, "lon": -74.075},
    {"match": 61, "group": "I", "date": "2026-06-26", "time": "15:00", "tz": "UTC-4", "team1": "Norway",              "team2": "France",              "stadium": "Gillette Stadium",        "city_name": "Foxborough",     "country": "USA",    "lat": 42.091, "lon": -71.264},
    {"match": 62, "group": "I", "date": "2026-06-26", "time": "15:00", "tz": "UTC-4", "team1": "Senegal",             "team2": "Iraq",                "stadium": "BMO Field",               "city_name": "Toronto",        "country": "Canada", "lat": 43.633, "lon": -79.419},

    # Group J
    {"match": 19, "group": "J", "date": "2026-06-16", "time": "20:00", "tz": "UTC-5", "team1": "Argentina",           "team2": "Algeria",             "stadium": "Arrowhead Stadium",       "city_name": "Kansas City",    "country": "USA",    "lat": 39.049, "lon": -94.484},
    {"match": 20, "group": "J", "date": "2026-06-16", "time": "21:00", "tz": "UTC-7", "team1": "Austria",             "team2": "Jordan",              "stadium": "Levi's Stadium",          "city_name": "Santa Clara",    "country": "USA",    "lat": 37.403, "lon": -121.970},
    {"match": 43, "group": "J", "date": "2026-06-22", "time": "12:00", "tz": "UTC-5", "team1": "Argentina",           "team2": "Austria",             "stadium": "AT&T Stadium",            "city_name": "Dallas",         "country": "USA",    "lat": 32.748, "lon": -97.093},
    {"match": 44, "group": "J", "date": "2026-06-22", "time": "20:00", "tz": "UTC-7", "team1": "Jordan",              "team2": "Algeria",             "stadium": "Levi's Stadium",          "city_name": "Santa Clara",    "country": "USA",    "lat": 37.403, "lon": -121.970},
    {"match": 69, "group": "J", "date": "2026-06-27", "time": "21:00", "tz": "UTC-5", "team1": "Algeria",             "team2": "Austria",             "stadium": "Arrowhead Stadium",       "city_name": "Kansas City",    "country": "USA",    "lat": 39.049, "lon": -94.484},
    {"match": 70, "group": "J", "date": "2026-06-27", "time": "21:00", "tz": "UTC-5", "team1": "Jordan",              "team2": "Argentina",           "stadium": "AT&T Stadium",            "city_name": "Dallas",         "country": "USA",    "lat": 32.748, "lon": -97.093},

    # Group K
    {"match": 23, "group": "K", "date": "2026-06-17", "time": "12:00", "tz": "UTC-5", "team1": "Portugal",            "team2": "DR Congo",            "stadium": "NRG Stadium",             "city_name": "Houston",        "country": "USA",    "lat": 29.685, "lon": -95.411},
    {"match": 24, "group": "K", "date": "2026-06-17", "time": "20:00", "tz": "UTC-6", "team1": "Uzbekistan",          "team2": "Colombia",            "stadium": "Estadio Azteca",          "city_name": "Mexico City",    "country": "Mexico", "lat": 19.303, "lon": -99.151},
    {"match": 47, "group": "K", "date": "2026-06-23", "time": "12:00", "tz": "UTC-5", "team1": "Portugal",            "team2": "Uzbekistan",          "stadium": "NRG Stadium",             "city_name": "Houston",        "country": "USA",    "lat": 29.685, "lon": -95.411},
    {"match": 48, "group": "K", "date": "2026-06-23", "time": "20:00", "tz": "UTC-6", "team1": "Colombia",            "team2": "DR Congo",            "stadium": "Estadio Akron",           "city_name": "Zapopan",        "country": "Mexico", "lat": 20.689, "lon": -103.467},
    {"match": 71, "group": "K", "date": "2026-06-27", "time": "19:30", "tz": "UTC-4", "team1": "Colombia",            "team2": "Portugal",            "stadium": "Hard Rock Stadium",       "city_name": "Miami Gardens",  "country": "USA",    "lat": 25.958, "lon": -80.239},
    {"match": 72, "group": "K", "date": "2026-06-27", "time": "19:30", "tz": "UTC-4", "team1": "DR Congo",            "team2": "Uzbekistan",          "stadium": "Mercedes-Benz Stadium",   "city_name": "Atlanta",        "country": "USA",    "lat": 33.755, "lon": -84.401},

    # Group L
    {"match": 22, "group": "L", "date": "2026-06-17", "time": "15:00", "tz": "UTC-5", "team1": "England",             "team2": "Croatia",             "stadium": "AT&T Stadium",            "city_name": "Dallas",         "country": "USA",    "lat": 32.748, "lon": -97.093},
    {"match": 21, "group": "L", "date": "2026-06-17", "time": "19:00", "tz": "UTC-4", "team1": "Ghana",               "team2": "Panama",              "stadium": "BMO Field",               "city_name": "Toronto",        "country": "Canada", "lat": 43.633, "lon": -79.419},
    {"match": 45, "group": "L", "date": "2026-06-23", "time": "16:00", "tz": "UTC-4", "team1": "England",             "team2": "Ghana",               "stadium": "Gillette Stadium",        "city_name": "Foxborough",     "country": "USA",    "lat": 42.091, "lon": -71.264},
    {"match": 46, "group": "L", "date": "2026-06-23", "time": "19:00", "tz": "UTC-4", "team1": "Panama",              "team2": "Croatia",             "stadium": "BMO Field",               "city_name": "Toronto",        "country": "Canada", "lat": 43.633, "lon": -79.419},
    {"match": 67, "group": "L", "date": "2026-06-27", "time": "17:00", "tz": "UTC-4", "team1": "Panama",              "team2": "England",             "stadium": "MetLife Stadium",         "city_name": "East Rutherford","country": "USA",    "lat": 40.814, "lon": -74.075},
    {"match": 68, "group": "L", "date": "2026-06-27", "time": "17:00", "tz": "UTC-4", "team1": "Croatia",             "team2": "Ghana",               "stadium": "Lincoln Financial Field", "city_name": "Philadelphia",   "country": "USA",    "lat": 39.901, "lon": -75.168},
]

# %%
matches = pd.DataFrame(matches)
matches['lat'] = matches['lat'].astype(float)
matches['lon'] = matches['lon'].astype(float)
# Melt so each row is one team's appearance in a game
team1_df = matches[['match', 'date', 'time', 'tz', 'team1', 'stadium', 'lat', 'lon', 'city_name', 'country']].copy()
team1_df = team1_df.rename(columns={'team1': 'team', 'team2': 'opponent'} if False else {'team1': 'team'})
team1_df['opponent'] = matches['team2']

team2_df = matches[['match', 'date', 'time', 'tz', 'team2', 'stadium','lat', 'lon', 'city_name', 'country']].copy()
team2_df = team2_df.rename(columns={'team2': 'team'})
team2_df['opponent'] = matches['team1']

long_df = pd.concat([team1_df, team2_df], ignore_index=True).sort_values(['team', 'date'])

# Number each team's games 1, 2, 3
long_df['game_num'] = long_df.groupby('team').cumcount() + 1

# Pivot wide — one row per team, columns for each game
result = long_df.pivot(index='team', columns='game_num',
                       values=['date', 'time', 'tz', 'stadium','lat', 'lon',  'city_name', 'country', 'opponent'])


# Flatten column names: date_1, date_2, ...
result.columns = [f'{col}_{num}' for col, num in result.columns]
result = result.reset_index()
for col in ['lat_1', 'lon_1', 'lat_2', 'lon_2', 'lat_3', 'lon_3']:
    result[col] = result[col].astype(float)

# %%
result[['lat_1', 'lat_2', 'lat_3']]
# Out:
#      lat_1   lat_2   lat_3
# 0   39.049  37.403  39.049
# 1   39.049  32.748  32.748
# 2   49.277  47.595  37.403
# 3   37.403  32.748  39.049
# 4   47.595  33.953  49.277
# 5   43.633  33.953  47.595
# 6   40.814  39.901  25.958
# 7   43.633  49.277  49.277
# 8   33.755  25.958  29.685
# 9   19.303  20.689  25.958
# 10  32.748  43.633  39.901
# 11  29.685  39.049  39.901
# 12  20.689  33.755  19.303
# 13  29.685  20.689  33.755
# 14  39.901  39.049  40.814
# 15  47.595  49.277  47.595
# 16  32.748  42.091  40.814
# 17  40.814  39.901  42.091
# 18  29.685  43.633  40.814
# 19  43.633  42.091  39.901
# 20  42.091  39.901  33.755
# 21  33.953  33.953  47.595
# 22  42.091  39.901  43.633
# 23  39.901  43.633  39.901
# 24  32.748  25.669  32.748
# 25  37.403  37.403  32.748
# 26  20.689  20.689  25.669
# 27  19.303  20.689  19.303
# 28  40.814  42.091  33.755
# 29  32.748  29.685  39.049
# 30  33.953  49.277  49.277
# 31  42.091  40.814  42.091
# 32  43.633  43.633  40.814
# 33  33.953  37.403  37.403
# 34  29.685  29.685  25.958
# 35  37.403  49.277  47.595
# 36  25.958  33.755  29.685
# 37  42.091  42.091  25.958
# 38  40.814  40.814  43.633
# 39  19.303  33.755  25.669
# 40  33.755  33.755  20.689
# 41  25.669  29.685  32.748
# 42  37.403  33.953  49.277
# 43  25.669  25.669  39.049
# 44  49.277  37.403  33.953
# 45  33.953  47.595  33.953
# 46  25.958  25.958  20.689
# 47  19.303  29.685  33.755

# %%
def haversine_vectorized(lat1, lon1, lat2, lon2):
    R = 6371.0  # Earth's radius in km
    # Convert degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    return R * c

# %%
flights_df = pd.read_csv('stadium_flight_distances.csv')

flight_lookup = flights_df.set_index(['origin_stadium', 'destination_stadium'])

def lookup_flight(row, from_col, to_col):
    origin = row[from_col]
    dest = row[to_col]

    r = flight_lookup.loc[(origin, dest)]
    
    return r['total_direct_flights'],  r['min_path_distance_km'], r['avg_drive_distance_km']


# Leg 1→2
result[['flights_1_2', 'flight_distance_1_2', 'airport_drive_dist_1_2']] = result.apply(
    lambda row: pd.Series(lookup_flight(row, 'stadium_1', 'stadium_2')) 
    if row['stadium_1'] != row['stadium_2'] else pd.Series([0, 0]), axis=1
)

# Leg 2→3
result[['flights_2_3', 'flight_distance_2_3', 'airport_drive_dist_2_3']] = result.apply(
    lambda row: pd.Series(lookup_flight(row, 'stadium_2', 'stadium_3')) 
    if row['stadium_2'] != row['stadium_3'] else pd.Series([0,  0]), axis=1
)

result['abs_dist_1_2'] = haversine_vectorized(result['lat_1'],result['lon_1'],result['lat_2'],result['lon_2'])
result['abs_dist_2_3'] = haversine_vectorized(result['lat_2'],result['lon_2'],result['lat_3'],result['lon_3'])


result
# Out:
#                       team      date_1      date_2      date_3 time_1 time_2  \
# 0                  Algeria  2026-06-16  2026-06-22  2026-06-27  20:00  20:00
# 1                Argentina  2026-06-16  2026-06-22  2026-06-27  20:00  12:00
# 2                Australia  2026-06-13  2026-06-19  2026-06-25  21:00  12:00
# 3                  Austria  2026-06-16  2026-06-22  2026-06-27  21:00  12:00
# 4                  Belgium  2026-06-15  2026-06-21  2026-06-26  12:00  12:00
# 5   Bosnia and Herzegovina  2026-06-12  2026-06-18  2026-06-24  15:00  12:00
# 6                   Brazil  2026-06-13  2026-06-19  2026-06-24  18:00  20:30
# 7                   Canada  2026-06-12  2026-06-18  2026-06-24  15:00  15:00
# 8               Cape Verde  2026-06-15  2026-06-21  2026-06-26  12:00  18:00
# 0                  Algeria   2398.783543   2398.783543
# 1                Argentina    738.901566      0.000000
# 2                Australia    195.678778   1133.683601
# 3                  Austria   2314.958096    738.901566
# 4                  Belgium   1553.175696   1748.621177
# 5   Bosnia and Herzegovina   3504.411592   1553.175696
# 6                   Brazil    137.415237   1620.233387
# 7                   Canada   3356.764329      0.000000
# 8               Cape Verde    955.118247   1547.135750
# 9                 Colombia    476.566093   2439.293616
# 10                 Croatia   1955.243866    544.364031
# 11                 Curaçao   1044.681269   1657.393445
# 12                 Czechia   2372.815420   2171.026415
# 13                DR Congo   1286.575248   2372.815420
# 14                 Ecuador   1657.393445   1747.213903
# 15                   Egypt    195.678778    195.678778
# 16                 England   2493.503527    273.922908
# 17                  France    137.415237    408.154250
# 18                 Germany   2099.703545    540.086690
# 19                   Ghana    686.113410    408.154250
# 20                   Haiti    408.154250   1067.754601
# 21                    Iran      0.000000   1553.175696
# 22                    Iraq    408.154250    544.364031
# 23             Ivory Coast    544.364031    544.364031
# 24                   Japan    844.436862    844.436862
# 25                  Jordan      0.000000   2314.958096
# 26          Korea Republic      0.000000    644.101507
# 27                  Mexico    476.566093    476.566093
# 28                 Morocco    273.922908   1475.864429
# 29             Netherlands    376.261254   1044.681269
# 30             New Zealand   1748.621177      0.000000
# 31                  Norway    273.922908    273.922908
# 32                  Panama      0.000000    540.086690
# 33                Paraguay    504.613034      0.000000
# 34                Portugal      0.000000   1547.135750
# 35                   Qatar   1323.512161    195.678778
# 36            Saudi Arabia    955.118247   1134.634079
# 37                Scotland      0.000000   1972.572536
# 38                 Senegal      0.000000    540.086690
# 39            South Africa   2171.026415   1771.715880
# 40                   Spain      0.000000   2372.815420
# 41                  Sweden    652.681249    376.261254
# 42             Switzerland    504.613034   1748.621177
# 43                 Tunisia      0.000000   1582.248136
# 44                 Türkiye   1323.512161    504.613034
# 45                     USA   1553.175696   1553.175696
# 46                 Uruguay      0.000000   2439.293616
# 47              Uzbekistan   1214.607805   1134.634079

# %%
result.to_csv('team_match_data.csv')

# %%
# Combine both legs into easier-to-work-with series
abs_dist = pd.concat([result['abs_dist_1_2'], result['abs_dist_2_3']])
flight_dist = pd.concat([result['flight_distance_1_2'], result['flight_distance_2_3']])
flights = pd.concat([result['flights_1_2'], result['flights_2_3']])

countries = pd.DataFrame({
    'from': pd.concat([result['country_1'], result['country_2']]).values,
    'to':   pd.concat([result['country_2'], result['country_3']]).values,
    'dist': abs_dist.values
})

summary = pd.DataFrame({
    'team': result['team'],
    
    # Number of legs where team stays at same stadium
    'same_stadium_count': (
        (result['abs_dist_1_2'] == 0).astype(int) + 
        (result['abs_dist_2_3'] == 0).astype(int)
    ),
    'drivable_count': (
        (result['flight_distance_1_2'] <500).astype(int) + 
        (result['flight_distance_2_3'] <500).astype(int)
    ),
    
    # Total physical distance travelled
    'total_direct_dist_km': result['abs_dist_1_2'] + result['abs_dist_2_3'],
    
    # Total flight distance, only counting legs > 500km
    'total_flight_dist_km': (
        result['flight_distance_1_2'].where(result['flight_distance_1_2'] > 500, 0) +
        result['flight_distance_2_3'].where(result['flight_distance_2_3'] > 500, 0)
    ),
    'total_drive_to_airport_dist_km': (
        result['airport_drive_dist_1_2'].where(result['flight_distance_1_2'] > 500, 0) +
        result['airport_drive_dist_2_3'].where(result['flight_distance_2_3'] > 500, 0)
    ),
        # Driving distance for legs <= 500km (using abs distance)
    'direct_driving_dist_km': (
        result['abs_dist_1_2'].where(result['flight_distance_1_2'] <= 500, 0) +
        result['abs_dist_2_3'].where(result['flight_distance_2_3'] <= 500, 0)
    ),
    

    
    # Number of border crossings (country changes, excluding same-stadium legs)
    'border_crossings': (
        ((result['country_1'] != result['country_2']) & (result['abs_dist_1_2'] > 0)).astype(int) +
        ((result['country_2'] != result['country_3']) & (result['abs_dist_2_3'] > 0)).astype(int)
    ),

    # Number of legs with no direct flights (flights == 0, excluding same-stadium)
    'no_direct_flights': (
        ((result['flights_1_2'] == 0) & (result['abs_dist_1_2'] > 0)).astype(int) +
        ((result['flights_2_3'] == 0) & (result['abs_dist_2_3'] > 0)).astype(int)
    ),
})

# %%
summary['all_driving_dist_km'] = summary['direct_driving_dist_km']+ summary['total_drive_to_airport_dist_km']
summary['travel_dist_km'] = summary['direct_driving_dist_km']+ summary['total_drive_to_airport_dist_km'] + summary['total_flight_dist_km']

# %%
summary = summary[[ 
    "team",
    "total_direct_dist_km",
    'total_flight_dist_km',
    'travel_dist_km',
    'all_driving_dist_km',
    "direct_driving_dist_km",
        "total_drive_to_airport_dist_km",
    "total_flight_dist_km",
    "border_crossings",
    "no_direct_flights",
    "same_stadium_count",
    "drivable_count"
]]

# %%
summary
# Out:
#                       team  total_direct_dist_km  travel_dist_km  \
# 0                  Algeria           4797.567087     4909.590702
# 1                Argentina            738.901566      796.877983
# 2                Australia           1329.362378     1323.885121
# 3                  Austria           3053.859662     3158.487845
# 4                  Belgium           3301.796874     3332.761386
# 5   Bosnia and Herzegovina           5057.587289     5087.302441
# 6                   Brazil           1757.648624     1789.733567
# 7                   Canada           3356.764329     3434.507626
# 8               Cape Verde           2502.253997     2545.817276
# 9                 Colombia           2915.859709     3028.277566
# 10                 Croatia           2499.607897     2619.793942
# 11                 Curaçao           2702.074713     2830.060729
# 12                 Czechia           4543.841835     4589.054049
# 13                DR Congo           3659.390668     3772.030742
# 14                 Ecuador           3404.607347     3545.405431
# 15                   Egypt            391.357556      391.357556
# 16                 England           2767.426435     2850.845276
# 17                  France            545.569487      545.569487
# 18                 Germany           2639.790235     2725.093554
# 19                   Ghana           1094.267660     1189.857942
# 20                   Haiti           1475.908852     1527.616774
# 21                    Iran           1553.175696     1561.193747
# 22                    Iraq            952.518281     1039.471122
# 23             Ivory Coast           1088.728062     1262.633743
# 24                   Japan           1688.873723     1821.544105
# 25                  Jordan           2314.958096     2361.609863
# 26          Korea Republic            644.101507      738.764753
# 27                  Mexico            953.132185      953.132185
# 28                 Morocco           1749.787336     1787.180067
# 29             Netherlands           1420.942523     1471.168072
# 30             New Zealand           1748.621177     1771.567639
# 31                  Norway            547.845815      547.845815
# 32                  Panama            540.086690      602.423881
# 33                Paraguay            504.613034      504.613034
# 27                        0.000000              0.000000                 0
# 28                       59.834916           1453.422244                 0
# 29                       57.744836           1037.161981                 0
# 30                       85.371281           1686.196358                 1
# 31                        0.000000              0.000000                 0
# 32                       62.082462            540.341418                 1
# 33                        0.000000              0.000000                 0
# 34                       40.944323           1537.827968                 0
# 35                       80.324513           1231.359526                 2
# 36                       67.726651           2044.003936                 0
# 37                       63.656212           1916.168308                 0
# 38                       62.082462            540.341418                 1
# 39                      101.244957           3888.637663                 2
# 40                       38.075139           2363.848835                 1
# 41                       67.850086            661.745132                 1
# 42                       85.371281           1686.196358                 1
# 43                       78.131197           1587.099416                 1
# 44                       80.324513           1231.359526                 1
# 45                      103.116205           3019.271289                 0
# 46                       41.896435           2509.815038                 1
# 47                       91.199295           2339.241459                 1
#
#     no_direct_flights  same_stadium_count  drivable_count
# 0                   0                   0               0
# 1                   0                   1               1
# 2                   0                   0               1
# 3                   0                   0               0
# 4                   0                   0               0
# 5                   0                   0               0
# 6                   0                   0               1
# 7                   0                   1               1
# 8                   0                   0               0
# 9                   1                   0               1
# 10                  0                   0               0
# 11                  0                   0               0
# 12                  0                   0               0
# 13                  0                   0               0
# 14                  0                   0               0
# 15                  0                   0               2
# 16                  0                   0               1
# 17                  0                   0               2
# 18                  0                   0               0
# 19                  0                   0               1
# 20                  0                   0               1
# 21                  0                   1               1
# 22                  0                   0               1
# 23                  0                   0               0
# 24                  0                   0               0
# 25                  0                   1               1
# 26                  0                   1               1
# 27                  0                   0               2
# 28                  0                   0               1
# 29                  0                   0               1
# 30                  0                   1               1
# 31                  0                   0               2
# 32                  0                   1               1
# 33                  0                   1               2
# 34                  0                   1               1
# 35                  0                   0               1
# 36                  0                   0               0
# 37                  0                   1               1
# 38                  0                   1               1
# 39                  0                   0               0
# 40                  0                   1               1
# 41                  0                   0               1
# 42                  0                   0               1
# 43                  1                   1               1
# 44                  0                   0               1
# 45                  0                   0               0
# 46                  1                   1               1
# 47                  0                   0               0

# %%
#summary.to_csv("team_follower_travel_summary.csv")

# %% [markdown]
# ## Stadium camp compilation

# %%
result.columns
# Out:
# Index(['team', 'date_1', 'date_2', 'date_3', 'time_1', 'time_2', 'time_3',
#        'tz_1', 'tz_2', 'tz_3', 'stadium_1', 'stadium_2', 'stadium_3', 'lat_1',
#        'lat_2', 'lat_3', 'lon_1', 'lon_2', 'lon_3', 'city_name_1',
#        'city_name_2', 'city_name_3', 'country_1', 'country_2', 'country_3',
#        'opponent_1', 'opponent_2', 'opponent_3', 'flights_1_2',
#        'flight_distance_1_2', 'airport_drive_dist_1_2', 'flights_2_3',
#        'flight_distance_2_3', 'airport_drive_dist_2_3', 'abs_dist_1_2',
#        'abs_dist_2_3'],
#       dtype='object')

# %%
result[result['team']=='South Africa']
# Out:
#             team      date_1      date_2      date_3 time_1 time_2 time_3  \
# 39  South Africa  2026-06-11  2026-06-18  2026-06-24  13:00  12:00  19:00
#
#      tz_1   tz_2   tz_3  ... opponent_2      opponent_3 flights_1_2  \
# 39  UTC-6  UTC-4  UTC-6  ...    Czechia  Korea Republic         8.0
#
#     flight_distance_1_2  airport_drive_dist_1_2  flights_2_3  \
# 39          2143.394506                43.73557          6.0
#
#     flight_distance_2_3  airport_drive_dist_2_3  abs_dist_1_2 abs_dist_2_3
# 39          1745.243157               57.509387   2171.026415   1771.71588
#
# [1 rows x 36 columns]

# %%
team_stadiums = result[['team', 'stadium_1', 'stadium_2', 'stadium_3']].copy()
camps_dist = pd.read_csv('flight_distances_camps_stadiums.csv')
camps_filt = camps_dist[[ 'camp_team', 'stadium_name', 'stad_camp_direct_distance_km']].copy()
team_stadiums = team_stadiums.merge(camps_filt, how='inner', left_on=['team', 'stadium_1'], right_on=['camp_team', 'stadium_name'])
team_stadiums.drop(columns=['stadium_name', 'camp_team'], inplace=True)
team_stadiums.rename(columns={'stad_camp_direct_distance_km':'stad1_camp_dist'},inplace=True)
team_stadiums.drop_duplicates(inplace=True)

team_stadiums = team_stadiums.merge(camps_filt, how='inner', left_on=['team', 'stadium_2'], right_on=['camp_team', 'stadium_name'])
team_stadiums.rename(columns={'stad_camp_direct_distance_km':'stad2_camp_dist'},inplace=True)
team_stadiums.drop(columns=['stadium_name', 'camp_team'], inplace=True)
team_stadiums = team_stadiums.merge(camps_filt, how='left', left_on=['team', 'stadium_3'], right_on=['camp_team', 'stadium_name'])
team_stadiums.rename(columns={'stad_camp_direct_distance_km':'stad3_camp_dist'},inplace=True)
team_stadiums.drop(columns=['stadium_name', 'camp_team'], inplace=True)
team_stadiums['total_distance'] = 2 * team_stadiums['stad1_camp_dist'] + 2 * team_stadiums['stad2_camp_dist'] + 2 * team_stadiums['stad3_camp_dist'] 

team_stadiums.drop_duplicates(inplace=True)
team_have_dist = team_stadiums[['team', 'total_distance']].copy()
team_have_dist.rename(columns={'total_distance':'total_distance_stadiums_camp'},inplace=True)
# def camp_to_stad(camp_df, stad_1, stad_2):
#     camp_df['']
# Out:
# /var/folders/6v/7nrd1rj91hx3tb4q5npbdf0w0000gn/T/ipykernel_44312/77319406.py:2: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   camps_dist = pd.read_csv('flight_distances_camps_stadiums.csv')

# %%
team_stadiums
# Out:
#                            team                stadium_1  \
# 0                       Algeria        Arrowhead Stadium
# 56784                 Argentina        Arrowhead Stadium
# 126480                Australia                 BC Place
# 247216                  Austria           Levi's Stadium
# 250450                  Belgium              Lumen Field
# 277450   Bosnia and Herzegovina                BMO Field
# 280618                   Brazil          MetLife Stadium
# 439868                   Canada                BMO Field
# 497468               Cape Verde    Mercedes-Benz Stadium
# 502588                 Colombia           Estadio Azteca
# 502908                  Croatia             AT&T Stadium
# 521784                  Curaçao              NRG Stadium
# 533016                  Czechia            Estadio Akron
# 547095                 DR Congo              NRG Stadium
# 549201                  Ecuador  Lincoln Financial Field
# 552009                    Egypt              Lumen Field
# 554649                  England             AT&T Stadium
# 659481                   France          MetLife Stadium
# 732281                  Germany              NRG Stadium
# 758645                    Ghana                BMO Field
# 831445                    Haiti         Gillette Stadium
# 848345                     Iran             SoFi Stadium
# 935663                     Iraq         Gillette Stadium
# 936287              Ivory Coast  Lincoln Financial Field
# 992603                    Japan             AT&T Stadium
# 992900                   Jordan           Levi's Stadium
# 1000446          Korea Republic            Estadio Akron
# 1000542                  Mexico           Estadio Azteca
# 1000596                 Morocco          MetLife Stadium
# 1277418             Netherlands             AT&T Stadium
# 1305066             New Zealand             SoFi Stadium
# 1494291                  Norway         Gillette Stadium
# 1529963                  Panama                BMO Field
# 1548839                Paraguay             SoFi Stadium
# 1681335                Portugal              NRG Stadium
# 1686455                   Qatar           Levi's Stadium
# 1697015            Saudi Arabia        Hard Rock Stadium
# 1702111                Scotland         Gillette Stadium
# 1707151                 Senegal          MetLife Stadium
# 2023051            South Africa           Estadio Azteca
# 2023090                   Spain    Mercedes-Benz Stadium
# 2023740                  Sweden             Estadio BBVA
# 2052252             Switzerland           Levi's Stadium
# 2279322                 Tunisia             Estadio BBVA
# 2279394                 Türkiye                 BC Place
# 2328786                     USA             SoFi Stadium
# 2452536                 Uruguay        Hard Rock Stadium
# 2452716              Uzbekistan           Estadio Azteca
#
#                        stadium_2                stadium_3  stad1_camp_dist  \
# 0                 Levi's Stadium        Arrowhead Stadium        67.519264
# 56784               AT&T Stadium             AT&T Stadium        29.566551
# 126480               Lumen Field           Levi's Stadium      1283.786135
# 247216              AT&T Stadium        Arrowhead Stadium       383.589792
# 250450              SoFi Stadium                 BC Place        13.223897
# 277450              SoFi Stadium              Lumen Field      2682.958839
# 280618   Lincoln Financial Field        Hard Rock Stadium         3.022991
# 439868                  BC Place                 BC Place      3367.183196
# 497468         Hard Rock Stadium              NRG Stadium       660.401769
# 502588             Estadio Akron        Hard Rock Stadium       462.323398
# 502908                 BMO Field  Lincoln Financial Field      1920.132763
# 521784         Arrowhead Stadium  Lincoln Financial Field      1545.836678
# 533016     Mercedes-Benz Stadium           Estadio Azteca      1460.625523
# 547095             Estadio Akron    Mercedes-Benz Stadium         6.929952
# 549201         Arrowhead Stadium          MetLife Stadium       665.303063
# 552009                  BC Place              Lumen Field       369.712793
# 554649          Gillette Stadium          MetLife Stadium       734.778641
# 659481   Lincoln Financial Field         Gillette Stadium       295.002661
# 732281                 BMO Field          MetLife Stadium      1581.656830
# 758645          Gillette Stadium  Lincoln Financial Field       670.868074
# 831445   Lincoln Financial Field    Mercedes-Benz Stadium       398.381703
# 848345              SoFi Stadium              Lumen Field       212.836649
# 935663   Lincoln Financial Field                BMO Field       906.334826
# 936287                 BMO Field  Lincoln Financial Field        19.518590
# 992603              Estadio BBVA             AT&T Stadium      1018.287193
# 992900            Levi's Stadium             AT&T Stadium       910.522009
# 1000446            Estadio Akron             Estadio BBVA         3.906365
# 1000542            Estadio Akron           Estadio Azteca        12.831557
# 1000596         Gillette Stadium    Mercedes-Benz Stadium        45.616406
# 1277418              NRG Stadium        Arrowhead Stadium       745.963758
# 1305066                 BC Place                 BC Place       169.526608
# 1494291          MetLife Stadium         Gillette Stadium       995.196983
# 1529963                BMO Field          MetLife Stadium        67.075393
# 1548839           Levi's Stadium           Levi's Stadium       497.440554
# 1681335              NRG Stadium        Hard Rock Stadium      1526.417994
# 1686455                 BC Place              Lumen Field       389.301911
# 1697015    Mercedes-Benz Stadium              NRG Stadium      1780.673601
# 35           276.003291              195.678778
# 36            67.726651                0.000000
# 37            63.656212                0.000000
# 38            62.082462                0.000000
# 39           101.244957                0.000000
# 40            38.075139                0.000000
# 41           444.111340              376.261254
# 42           589.984315              504.613034
# 43            78.131197                0.000000
# 44           584.937547              504.613034
# 45           103.116205                0.000000
# 46            41.896435                0.000000
# 47            91.199295                0.000000
#
#     total_drive_to_airport_dist_km  total_flight_dist_km  border_crossings  \
# 0                       128.396670           4781.194032                 0
# 1                        55.222685            741.655298                 0
# 2                        46.511334           1081.695009                 1
# 3                       106.617757           3051.870088                 0
# 4                       136.929384           3195.832002                 1
# 5                       125.646465           4961.655976                 1
# 6                        51.690867           1600.627463                 0
# 7                        88.995384           3345.512242                 0
# 8                        71.547947           2474.269329                 0
# 9                        41.896435           2509.815038                 1
# 10                      133.400583           2486.393359                 2
# 11                      126.236217           2703.824512                 0
# 12                       81.810709           4507.243341                 2
# 13                       86.490976           3685.539766                 2
# 14                      125.730584           3419.674846                 0
# 15                        0.000000              0.000000                 2
# 16                       67.653463           2509.268906                 0
# 17                        0.000000              0.000000                 0
# 18                      124.670557           2600.422996                 2
# 19                       85.299984            696.403708                 1
# 20                       47.869571           1071.592953                 0
# 21                       51.558103           1509.635644                 0
# 22                       73.334639            557.982232                 1
# 23                      146.669278           1115.964465                 2
# 24                      130.655869           1690.888236                 2
# 25                       51.395072           2310.214791                 0
# 26                       68.802198            669.962555                 0
# 27                        0.000000              0.000000                 0
# 28                       59.834916           1453.422244                 0
# 29                       57.744836           1037.161981                 0
# 30                       85.371281           1686.196358                 1
# 31                        0.000000              0.000000                 0
# 32                       62.082462            540.341418                 1
# 33                        0.000000              0.000000                 0
# 34                       40.944323           1537.827968                 0
# 35                       80.324513           1231.359526                 2
# 36                       67.726651           2044.003936                 0
# 37                       63.656212           1916.168308                 0
# 38                       62.082462            540.341418                 1
# 39                      101.244957           3888.637663                 2
# 40                       38.075139           2363.848835                 1
# 41                       67.850086            661.745132                 1
# 42                       85.371281           1686.196358                 1
# 43                       78.131197           1587.099416                 1
# 44                       80.324513           1231.359526                 1
# 45                      103.116205           3019.271289                 0
# 46                       41.896435           2509.815038                 1
# 47                       91.199295           2339.241459                 1
#
#     no_direct_flights  same_stadium_count  drivable_count  \
# 0                   0                   0               0
# 1                   0                   1               1
# 2                   0                   0               1
# 3                   0                   0               0
# 4                   0                   0               0
# 5                   0                   0               0
# 6                   0                   0               1
# 7                   0                   1               1
# 8                   0                   0               0
# 9                   1                   0               1
# 10                  0                   0               0
# 11                  0                   0               0
# 12                  0                   0               0
# 13                  0                   0               0
# 14                  0                   0               0
# 15                  0                   0               2
# 16                  0                   0               1
# 17                  0                   0               2
# 18                  0                   0               0
# 19                  0                   0               1
# 20                  0                   0               1
# 21                  0                   1               1
# 22                  0                   0               1
# 23                  0                   0               0
# 24                  0                   0               0
# 25                  0                   1               1
# 26                  0                   1               1
# 27                  0                   0               2
# 28                  0                   0               1
# 29                  0                   0               1
# 30                  0                   1               1
# 31                  0                   0               2
# 32                  0                   1               1
# 33                  0                   1               2
# 34                  0                   1               1
# 35                  0                   0               1
# 36                  0                   0               0
# 37                  0                   1               1
# 38                  0                   1               1
# 39                  0                   0               0
# 40                  0                   1               1
# 41                  0                   0               1
# 42                  0                   0               1
# 43                  1                   1               1
# 44                  0                   0               1
# 45                  0                   0               0
# 46                  1                   1               1
# 47                  0                   0               0
#
#     total_distance_stadiums_camp
# 0                    4936.193552
# 1                    2946.486685
# 2                    4843.982793
# 3                    9610.167318
# 4                    3524.766827
# 5                    9508.215946
# 6                    3770.454078
# 7                    6777.240422
# 8                    4503.540958
# 9                    5812.615179
# 10                   5393.012404
# 11                  10124.236211
# 12                   8281.306021
# 13                   4851.017850
# 14                   4836.675166
# 15                   2393.792940
# 16                   8952.990819
# 17                   1519.037330
# 18                   6336.178975
# 19                   2158.323471
# 20                   3110.339244
# 21                   4336.510938
# 22                   4128.004787
# 23                   1156.730907
# 24                   7534.910742
# 25                   8866.607890
# 26                   1301.141355
# 27                   1007.513684
# 28                   3047.325521
# 29                   3632.717190
# 30                   7939.414316
# 31                   5432.982587
# 32                   1472.063633
# 33                   1024.171269
# 34                   6314.303514
# 35                   7084.396458
# 36                   6649.408745
# 37                   6577.423913
# 38                   1251.447170
# 39                   5625.836518
# 40                   5456.358173
# 41                   2710.774935
# 42                   5375.026616
# 43                   3176.893982
# 44                   7320.913747
# 45                   3444.485886
# 46                   7043.745612
# 47                   6667.034582

# %%
def distances_plot(dist_summary_final_df, stadium_distance_column = 'total_direct_dist_km', camp_distance_column = 'total_distance_stadiums_camp', out_fp="total_distances.png"):
    '''Plots the stadium to stadium distance vs camp distance.
        Inputs:
            dist_summary_final_df: dataframe with 1 row per team. The required columns are
                    'team': the team name
                    stadium_distance_column: The total distances for all games for stadium to stadium travel. 
                                        For the original plot, the distances are measured as the distance stadium1-> stadium2 ->stadium3
                    camp_distance_column: The total distance that are traveled by a team.
                                        For the original plot, the distances are measured as camp->stad1-> camp ->stad2->camp->stad3-> camp  
                    'out_fp': the filepath to save the file'''
    fig, ax = plt.subplots(figsize=(6, 7))

    ax.scatter(dist_summary_final_df[stadium_distance_column], dist_summary_final_df[camp_distance_column], zorder=3)

    for team, row in dist_summary_final_df.iterrows():
        ax.annotate(row['team'], (row[stadium_distance_column], row[camp_distance_column]),
                    textcoords='offset points', xytext=(6, 4), fontsize=9)

    ax.set_xlabel('stadium to stadium travel total distance (km)')
    ax.set_ylabel('team travel total distance (km)')
    ax.set_aspect('equal')
    ax.set_title('Stadium to stadium vs team total travel distances')
    ax.grid(True, linestyle='--', alpha=0.5)

    plt.tight_layout()
    max_val_y = dist_summary_final_df[camp_distance_column].max()
    max_val_x = dist_summary_final_df[stadium_distance_column].max()
    ax.set_xlim(0, max_val_x)
    ax.set_ylim(0, max_val_y)

    # Use the same ticks on both axes
    ticks_x = np.arange(0, max_val_x + 1000, 1000)
    ticks_y = np.arange(0, max_val_y + 1000, 1000)
    ax.set_xticks(ticks_x)
    ax.set_yticks(ticks_y)
    plt.savefig(out_fp)
distances_plot(dist_summary_final_df, stadium_distance_column='tota')
